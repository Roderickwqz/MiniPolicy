# %%
import os
import sys
import json
from pathlib import Path
import dotenv

sys.path.append("/home/roder/projects/test/MiniPolicy")
from app.mcp.tools.pdf_ingest import pdf_ingest_tool
from app.mcp.tools.vector_index import vector_index_tool
from app.mcp.tools.semantic_retrieve import semantic_retrieve_tool
dotenv.load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       5 import dotenv
#       7 sys.path.append("/home/roder/projects/test/MiniPolicy")
# ----> 8 from app.mcp.tools.pdf_ingest import pdf_ingest_tool
#       9 from app.mcp.tools.vector_index import vector_index_tool
#      10 from app.mcp.tools.semantic_retrieve import semantic_retrieve_tool
#
# File ~/projects/test/MiniPolicy/app/mcp/tools/pdf_ingest.py:14
#      10 import threading
#      12 from app.mcp.contracts import ToolError, ToolResult
# ---> 14 from llama_index.core import SimpleDirectoryReader, Document
#      15 from llama_index.readers.file import PyMuPDFReader
#      16 from llama_index.core.node_parser import SentenceSplitter, SemanticSplitterNodeParser
#
# ModuleNotFoundError: No module named 'llama_index'

# %%
class test():
    def __init__(self):
        self.asshole = 'bog'

baga = test()

# %%
_stable_json(baga)
# Out:
# '"<__main__.test object at 0x7f88e15e92b0>"'
