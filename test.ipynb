# %%
import os
import sys
import json
from pathlib import Path
import dotenv

sys.path.append("/home/roder/projects/test/MiniPolicy")
from app.mcp.tools.pdf_ingest import pdf_ingest_tool
from app.mcp.tools.vector_index import vector_index_tool
from app.mcp.tools.semantic_retrieve import semantic_retrieve_tool
dotenv.load_dotenv()
# Out:
# Loaded .env file from: /home/roder/projects/test/MiniPolicy/.env
# True

# %%
from app.mcp.config import get_weaviate_client_config

# %%
get_weaviate_client_config()
# Out:
# {'host': 'localhost',
#  'port': 22006,
#  'grpc_port': 50051,
#  'scheme': 'http',
#  'url': 'http://localhost:22006'}
